# %% [markdown]
# ## Simple Returns - Part II

# %% [markdown]
# $$
# \frac{P_1 - P_0}{P_0} = \frac{P_1}{P_0} - 1
# $$

# %%
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

MSFT = wb.DataReader('MSFT', data_source='yahoo', start='2000-1-1')
MSFT['simple_return'] = (MSFT['Adj Close'] / MSFT['Adj Close'].shift(1)) - 1
print (MSFT['simple_return'])
# Out:
# Date
# 2000-01-03         NaN
# 2000-01-04   -0.033780
# 2000-01-05    0.010544
# 2000-01-06   -0.033498
# 2000-01-07    0.013068
#                 ...
# 2020-03-20   -0.037559
# 2020-03-23   -0.009975
# 2020-03-24    0.090896
# 2020-03-25   -0.009573
# 2020-03-26    0.047645
# Name: simple_return, Length: 5090, dtype: float64

# %% [markdown]
# Plot the simple returns on a graph.

# %%
MSFT['simple_return'].plot(figsize = (8, 5))
plt.show()

# %% [markdown]
# Calculate the average daily return.

# %%
avg_return_d = MSFT['simple_return'].mean()
print('The daily average return is: ' + str(round(avg_return_d,5)) + '%')
# Out:
# The daily average return is: 0.00047%

# %% [markdown]
# Estimate the average annual return.

# %%
avg_return_a = avg_return_d * 250

# %% [markdown]
# Print the percentage version of the result as a float with 2 digits after the decimal point.

# %%
print('The annual average return is: ' + str(round(avg_return_a,4)) + '%')
# Out:
# The annual average return is: 0.1167%
